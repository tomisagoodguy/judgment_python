# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os
import time
import random
import re


def crawl_foi_decisions(session: requests.Session, url: str, keyword: str) -> pd.DataFrame:
    """
    爬取金融消費評議中心(FOI)的評議決定書列表。

    本函數會模擬使用者在網站上進行查詢的操作，
    首先發送一個 GET 請求以獲取表單需要的驗證資訊 (VIEWSTATE)，
    然後帶上查詢條件發送 POST 請求來取得搜尋結果。
    最後，解析結果頁面的 HTML，並將資料整理成 Pandas DataFrame。

    Args:
        session (requests.Session): 用於保持連線狀態的 Session 物件。
        url (str): 要爬取的目標網站 URL。
        keyword (str): 內容檢索的關鍵字。

    Returns:
        pd.DataFrame: 包含評議案件資訊的 DataFrame，
                      欄位包括 '評議字號', '評議決定日期', '爭議類型', '下載連結'。
                      如果爬取失敗或沒有找到結果，則返回一個空的 DataFrame。
    """
    try:
        # --- 步驟 1: 發送 GET 請求以獲取初始表單資訊 ---
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        res_get = session.get(url, headers=headers, timeout=15)
        res_get.raise_for_status()

        soup_get = BeautifulSoup(res_get.text, 'html.parser')

        viewstate = soup_get.find(id='__VIEWSTATE').get('value')
        viewstategenerator = soup_get.find(
            id='__VIEWSTATEGENERATOR').get('value')

        # --- 步驟 2: 準備 POST 請求的表單資料 (payload) ---
        form_data = {
            '__EVENTTARGET': '',
            '__EVENTARGUMENT': '',
            '__LASTFOCUS': '',
            '__VIEWSTATE': viewstate,
            '__VIEWSTATEGENERATOR': viewstategenerator,
            'Foi$cph_content$ddlTypeID': 'I03',
            'Foi$cph_content$ddl_page': '100',
            'Foi$cph_content$ddl_ResultKind': 'I03001',
            'Foi$cph_content$hResName': '申請人主張有理由',
            'Foi$cph_content$ddlVerticals': '0',
            'Foi$cph_content$ddlSubVerticals': '0',
            'Foi$cph_content$dll_ControversyKind': '0',
            'Foi$cph_content$txt_BYear': '',
            'Foi$cph_content$dll_BCase': '評',
            'Foi$cph_content$txt_Bno': '',
            'Foi$cph_content$txt_Content': keyword,
            'Foi$cph_content$txt_Syear': '',
            'Foi$cph_content$txt_Smonth': '',
            'Foi$cph_content$txt_Sday': '',
            'Foi$cph_content$txt_Eyear': '',
            'Foi$cph_content$txt_Emonth': '',
            'Foi$cph_content$txt_Eday': '',
            'Foi$cph_content$btn_submit': '送出查詢',
            'Foi$cph_content$ddlOrderBy': '1',  # 依照日期由新到舊排序
            'Foi$cph_content$hSort': '1',
        }

        # --- 步驟 3: 發送 POST 請求以取得查詢結果 ---
        res_post = session.post(url, data=form_data,
                                headers=headers, timeout=15)
        res_post.raise_for_status()

        # --- 步驟 4: 解析查詢結果頁面 ---
        soup_post = BeautifulSoup(res_post.text, 'html.parser')
        result_div = soup_post.find(id='cph_content_PnShowResult')
        if not result_div:
            print("找不到查詢結果區塊。")
            return pd.DataFrame()

        result_table = result_div.find('table')
        if not result_table:
            print("找不到查詢結果表格。")
            return pd.DataFrame()

        # --- 步驟 5: 提取資料並存入 List ---
        data_rows = []
        rows = result_table.find_all('tr')[1:]

        for i in range(0, len(rows), 2):
            main_row = rows[i]
            cols = main_row.find_all('td')

            case_number_tag = cols[2].find('a')
            if case_number_tag:
                # 組合完整的下載連結
                download_link = url.rsplit(
                    '/', 1)[0] + '/' + case_number_tag['href'].strip()
            else:
                continue  # 如果沒有連結，跳過此筆

            data_rows.append({
                '評議字號': case_number_tag.text.strip(),
                '評議決定日期': cols[3].text.strip(),
                '爭議類型': cols[4].text.strip(),
                '下載連結': download_link,
            })

        # --- 步驟 6: 建立 Pandas DataFrame ---
        return pd.DataFrame(data_rows)

    except requests.exceptions.RequestException as e:
        print(f"網路請求錯誤: {e}")
        return pd.DataFrame()
    except Exception as e:
        print(f"處理過程中發生錯誤: {e}")
        return pd.DataFrame()


def sanitize_filename(filename: str) -> str:
    """
    清理檔案名稱，移除不合法的字元。

    Args:
        filename (str): 原始檔案名稱。

    Returns:
        str: 清理過後的檔案名稱。
    """
    return re.sub(r'[\\/*?:"<>|]', "", filename)


def download_articles_as_pdf(session: requests.Session, df: pd.DataFrame, output_dir: str):
    """
    遍歷 DataFrame，直接下載連結中的 PDF 檔案並儲存。

    Args:
        session (requests.Session): 用於保持連線狀態的 Session 物件。
        df (pd.DataFrame): 包含案件資訊的 DataFrame。
        output_dir (str): PDF 檔案的儲存目錄。
    """
    if df.empty:
        print("沒有可下載的資料。")
        return

    # 確保輸出目錄存在
    os.makedirs(output_dir, exist_ok=True)
    print(f"PDF 將儲存至: {os.path.abspath(output_dir)}")

    total_files = len(df)
    for index, row in df.iterrows():
        try:
            # --- 步驟 1: 建立 PDF 檔案名稱並檢查是否已存在 ---
            seq_num = f"{index + 1:03d}"
            case_num_sanitized = sanitize_filename(row['評議字號'])
            dispute_type_sanitized = sanitize_filename(row['爭議類型'])

            pdf_filename = f"{seq_num}_{case_num_sanitized}_{dispute_type_sanitized}.pdf"
            pdf_filepath = os.path.join(output_dir, pdf_filename)

            if os.path.exists(pdf_filepath):
                print(f"[{index + 1}/{total_files}] 已存在，跳過: {pdf_filename}")
                continue

            # --- 步驟 2: 溫和爬蟲機制 ---
            sleep_time = random.uniform(1.0, 2.5)
            print(
                f"[{index + 1}/{total_files}] 準備下載: {pdf_filename} (等待 {sleep_time:.2f} 秒)")
            time.sleep(sleep_time)

            # --- 步驟 3: 下載 PDF 檔案 ---
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
            pdf_res = session.get(row['下載連結'], headers=headers, timeout=30)
            pdf_res.raise_for_status()

            # --- 步驟 4: 將二進位內容寫入檔案 ---
            # 使用 'wb' (write binary) 模式來寫入 PDF 檔案
            with open(pdf_filepath, 'wb') as f:
                f.write(pdf_res.content)

            print(f"----> 成功儲存: {pdf_filename}")

        except requests.exceptions.RequestException as e:
            print(f"----! 下載失敗: {row['評議字號']}，錯誤: {e}")
        except Exception as e:
            print(f"----! 儲存檔案時發生錯誤: {row['評議字號']}，錯誤: {e}")


if __name__ == '__main__':
    # --- 設定區 ---
    target_url = 'https://ods.foi.org.tw/'
    search_keyword = 'prp 韌帶 或 prp半月板'
    output_directory = '金融評議決定書_PRP'  # 將資料夾名稱改得更具體

    # 建立共用的 Session
    with requests.Session() as session:
        # 執行爬蟲函數，取得案件列表
        print("開始爬取案件列表...")
        df_results = crawl_foi_decisions(session, target_url, search_keyword)

        if not df_results.empty:
            print(f"成功爬取到 {len(df_results)} 筆案件列表。")

            # 執行下載 PDF 的函數
            download_articles_as_pdf(session, df_results, output_directory)

            print("\n所有任務完成。")
        else:
            print("未能爬取到任何案件列表，程式結束。")
# Out:
# 開始爬取案件列表...
# 成功爬取到 100 筆案件列表。
# PDF 將儲存至: c:\Users\user\Documents\GitHub\judgment_python\金融評議決定書_PRP
# [1/100] 準備下載: 001_113年評字第005616號_違反告知義務.pdf (等待 1.39 秒)
# ----> 成功儲存: 001_113年評字第005616號_違反告知義務.pdf
# [2/100] 準備下載: 002_114年評字第000223號_投保時已患疾病或在妊娠中.pdf (等待 2.47 秒)
# ----> 成功儲存: 002_114年評字第000223號_投保時已患疾病或在妊娠中.pdf
# [3/100] 準備下載: 003_114年評字第000268號_必要性醫療.pdf (等待 1.01 秒)
# ----> 成功儲存: 003_114年評字第000268號_必要性醫療.pdf
# [4/100] 準備下載: 004_114年評字第000635號_必要性醫療.pdf (等待 1.12 秒)
# ----> 成功儲存: 004_114年評字第000635號_必要性醫療.pdf
# [5/100] 準備下載: 005_114年評字第000193號_必要性醫療.pdf (等待 1.19 秒)
# ----> 成功儲存: 005_114年評字第000193號_必要性醫療.pdf
# [6/100] 準備下載: 006_113年評字第005556號_失能或豁免保費體況認定.pdf (等待 2.25 秒)
# ----> 成功儲存: 006_113年評字第005556號_失能或豁免保費體況認定.pdf
# [7/100] 準備下載: 007_113年評字第004478號_違反告知義務.pdf (等待 1.20 秒)
# ----> 成功儲存: 007_113年評字第004478號_違反告知義務.pdf
# [8/100] 準備下載: 008_113年評字第004593號_違反告知義務.pdf (等待 1.75 秒)
# ----> 成功儲存: 008_113年評字第004593號_違反告知義務.pdf
# [9/100] 準備下載: 009_113年評字第004982號_契約效力爭議.pdf (等待 1.19 秒)
# ----> 成功儲存: 009_113年評字第004982號_契約效力爭議.pdf
# [10/100] 準備下載: 010_113年評字第005222號_必要性醫療.pdf (等待 1.51 秒)
# ----> 成功儲存: 010_113年評字第005222號_必要性醫療.pdf
# [11/100] 準備下載: 011_113年評字第004806號_醫療單據認定.pdf (等待 2.26 秒)
# ----> 成功儲存: 011_113年評字第004806號_醫療單據認定.pdf
# [12/100] 準備下載: 012_113年評字第004847號_承保範圍.pdf (等待 1.64 秒)
# ----> 成功儲存: 012_113年評字第004847號_承保範圍.pdf
# [13/100] 準備下載: 013_113年評字第003993號_等待期間發生或確診之疾病認定.pdf (等待 2.02 秒)
# ----> 成功儲存: 013_113年評字第003993號_等待期間發生或確診之疾病認定.pdf
# [14/100] 準備下載: 014_113年評字第004590號_失能或豁免保費體況認定.pdf (等待 2.32 秒)
# ----> 成功儲存: 014_113年評字第004590號_失能或豁免保費體況認定.pdf
# [15/100] 準備下載: 015_113年評字第002213號_承保範圍.pdf (等待 2.32 秒)
# ----> 成功儲存: 015_113年評字第002213號_承保範圍.pdf
# [16/100] 準備下載: 016_113年評字第004399號_事故發生原因認定.pdf (等待 1.97 秒)
# ----> 成功儲存: 016_113年評字第004399號_事故發生原因認定.pdf
# [17/100] 準備下載: 017_113年評字第004651號_違反告知義務.pdf (等待 2.24 秒)
# ----> 成功儲存: 017_113年評字第004651號_違反告知義務.pdf
# [18/100] 準備下載: 018_113年評字第004801號_失能等級認定.pdf (等待 1.51 秒)
# ----> 成功儲存: 018_113年評字第004801號_失能等級認定.pdf
# [19/100] 準備下載: 019_113年評字第004295號_投保時已患疾病或在妊娠中.pdf (等待 1.53 秒)
# ----> 成功儲存: 019_113年評字第004295號_投保時已患疾病或在妊娠中.pdf
# [20/100] 準備下載: 020_113年評字第003943號_違反告知義務.pdf (等待 1.92 秒)
# ----> 成功儲存: 020_113年評字第003943號_違反告知義務.pdf
# [21/100] 準備下載: 021_113年評字第004433號_必要性醫療.pdf (等待 1.73 秒)
# ----> 成功儲存: 021_113年評字第004433號_必要性醫療.pdf
# [22/100] 準備下載: 022_113年評字第004322號_醫療單據認定.pdf (等待 2.07 秒)
# ----> 成功儲存: 022_113年評字第004322號_醫療單據認定.pdf
# [23/100] 準備下載: 023_113年評字第003466號_其他.pdf (等待 1.87 秒)
# ----> 成功儲存: 023_113年評字第003466號_其他.pdf
# [24/100] 準備下載: 024_113年評字第003798號_失能或豁免保費體況認定.pdf (等待 1.31 秒)
# ----> 成功儲存: 024_113年評字第003798號_失能或豁免保費體況認定.pdf
# [25/100] 準備下載: 025_113年評字第003555號_事故發生原因認定.pdf (等待 1.34 秒)
# ----> 成功儲存: 025_113年評字第003555號_事故發生原因認定.pdf
# [26/100] 準備下載: 026_113年評字第003878號_必要性醫療.pdf (等待 1.81 秒)
# ----> 成功儲存: 026_113年評字第003878號_必要性醫療.pdf
# [27/100] 準備下載: 027_113年評字第003003號_失能等級認定.pdf (等待 2.33 秒)
# ----> 成功儲存: 027_113年評字第003003號_失能等級認定.pdf
# [28/100] 準備下載: 028_113年評字第003288號_投保時已患疾病或在妊娠中.pdf (等待 1.48 秒)
# ----> 成功儲存: 028_113年評字第003288號_投保時已患疾病或在妊娠中.pdf
# [29/100] 準備下載: 029_113年評字第003314號_投保時已患疾病或在妊娠中.pdf (等待 1.65 秒)
# ----> 成功儲存: 029_113年評字第003314號_投保時已患疾病或在妊娠中.pdf
# [30/100] 準備下載: 030_113年評字第003701號_失能或豁免保費體況認定.pdf (等待 2.09 秒)
# ----> 成功儲存: 030_113年評字第003701號_失能或豁免保費體況認定.pdf
# [31/100] 準備下載: 031_113年評字第003450號_失能或豁免保費體況認定.pdf (等待 2.14 秒)
# ----> 成功儲存: 031_113年評字第003450號_失能或豁免保費體況認定.pdf
# [32/100] 準備下載: 032_113年評字第003255號_業務招攬爭議.pdf (等待 2.17 秒)
# ----> 成功儲存: 032_113年評字第003255號_業務招攬爭議.pdf
# [33/100] 準備下載: 033_113年評字第002873號_事故發生原因認定.pdf (等待 1.04 秒)
# ----> 成功儲存: 033_113年評字第002873號_事故發生原因認定.pdf
# [34/100] 準備下載: 034_113年評字第003372號_除外責任.pdf (等待 2.45 秒)
# ----> 成功儲存: 034_113年評字第003372號_除外責任.pdf
# [35/100] 準備下載: 035_113年評字第002548號_投保時已患疾病或在妊娠中.pdf (等待 2.09 秒)
# ----> 成功儲存: 035_113年評字第002548號_投保時已患疾病或在妊娠中.pdf
# [36/100] 準備下載: 036_113年評字第002740號_投保時已患疾病或在妊娠中.pdf (等待 1.52 秒)
# ----> 成功儲存: 036_113年評字第002740號_投保時已患疾病或在妊娠中.pdf
# [37/100] 準備下載: 037_113年評字第002964號_投保時已患疾病或在妊娠中.pdf (等待 1.60 秒)
# ----> 成功儲存: 037_113年評字第002964號_投保時已患疾病或在妊娠中.pdf
# [38/100] 準備下載: 038_113年評字第002803號_承保範圍.pdf (等待 2.47 秒)
# ----> 成功儲存: 038_113年評字第002803號_承保範圍.pdf
# [39/100] 準備下載: 039_113年評字第001845號_投保時已患疾病或在妊娠中.pdf (等待 1.32 秒)
# ----> 成功儲存: 039_113年評字第001845號_投保時已患疾病或在妊娠中.pdf
# [40/100] 準備下載: 040_113年評字第002053號_事故發生原因認定.pdf (等待 2.03 秒)
# ----> 成功儲存: 040_113年評字第002053號_事故發生原因認定.pdf
# [41/100] 準備下載: 041_113年評字第002550號_事故發生原因認定.pdf (等待 1.22 秒)
# ----> 成功儲存: 041_113年評字第002550號_事故發生原因認定.pdf
# [42/100] 準備下載: 042_113年評字第002628號_醫療單據認定.pdf (等待 1.76 秒)
# ----> 成功儲存: 042_113年評字第002628號_醫療單據認定.pdf
# [43/100] 準備下載: 043_113年評字第001691號_投保時已患疾病或在妊娠中.pdf (等待 2.07 秒)
# ----> 成功儲存: 043_113年評字第001691號_投保時已患疾病或在妊娠中.pdf
# [44/100] 準備下載: 044_113年評字第000996號_信用卡消費款爭議.pdf (等待 1.32 秒)
# ----> 成功儲存: 044_113年評字第000996號_信用卡消費款爭議.pdf
# [45/100] 準備下載: 045_113年評字第001504號_停效復效爭議.pdf (等待 2.49 秒)
# ----> 成功儲存: 045_113年評字第001504號_停效復效爭議.pdf
# [46/100] 準備下載: 046_113年評字第001548號_違反告知義務.pdf (等待 1.62 秒)
# ----> 成功儲存: 046_113年評字第001548號_違反告知義務.pdf
# [47/100] 準備下載: 047_113年評字第001217號_停效復效爭議.pdf (等待 1.74 秒)
# ----> 成功儲存: 047_113年評字第001217號_停效復效爭議.pdf
# [48/100] 準備下載: 048_113年評字第000688號_停效復效爭議.pdf (等待 1.34 秒)
# ----> 成功儲存: 048_113年評字第000688號_停效復效爭議.pdf
# [49/100] 準備下載: 049_113年評字第001669號_必要性醫療.pdf (等待 1.66 秒)
# ----> 成功儲存: 049_113年評字第001669號_必要性醫療.pdf
# [50/100] 準備下載: 050_113年評字第000412號_解約爭議.pdf (等待 1.28 秒)
# ----> 成功儲存: 050_113年評字第000412號_解約爭議.pdf
# [51/100] 準備下載: 051_113年評字第000643號_理賠金額認定.pdf (等待 1.19 秒)
# ----> 成功儲存: 051_113年評字第000643號_理賠金額認定.pdf
# [52/100] 準備下載: 052_113年評字第000958號_遲延給付.pdf (等待 1.47 秒)
# ----> 成功儲存: 052_113年評字第000958號_遲延給付.pdf
# [53/100] 準備下載: 053_113年評字第000071號_停效復效爭議.pdf (等待 2.11 秒)
# ----> 成功儲存: 053_113年評字第000071號_停效復效爭議.pdf
# [54/100] 準備下載: 054_113年評字第000432號_必要性醫療.pdf (等待 1.38 秒)
# ----> 成功儲存: 054_113年評字第000432號_必要性醫療.pdf
# [55/100] 準備下載: 055_113年評字第001153號_必要性醫療.pdf (等待 1.93 秒)
# ----> 成功儲存: 055_113年評字第001153號_必要性醫療.pdf
# [56/100] 準備下載: 056_113年評字第000623號_違反告知義務.pdf (等待 1.55 秒)
# ----> 成功儲存: 056_113年評字第000623號_違反告知義務.pdf
# [57/100] 準備下載: 057_112年評字第001597號_停效復效爭議.pdf (等待 1.18 秒)
# ----> 成功儲存: 057_112年評字第001597號_停效復效爭議.pdf
# [58/100] 準備下載: 058_112年評字第001176號_理賠金額認定.pdf (等待 1.73 秒)
# ----> 成功儲存: 058_112年評字第001176號_理賠金額認定.pdf
# [59/100] 準備下載: 059_112年評字第004242號_理賠金額認定.pdf (等待 2.00 秒)
# ----> 成功儲存: 059_112年評字第004242號_理賠金額認定.pdf
# [60/100] 準備下載: 060_112年評字第002708號_承保範圍.pdf (等待 1.91 秒)
# ----> 成功儲存: 060_112年評字第002708號_承保範圍.pdf
# [61/100] 準備下載: 061_112年評字第003263號_投保時已患疾病或在妊娠中.pdf (等待 2.31 秒)
# ----> 成功儲存: 061_112年評字第003263號_投保時已患疾病或在妊娠中.pdf
# [62/100] 準備下載: 062_112年評字第003168號_承保範圍.pdf (等待 2.49 秒)
# ----> 成功儲存: 062_112年評字第003168號_承保範圍.pdf
# [63/100] 準備下載: 063_112年評字第002392號_失能或豁免保費體況認定.pdf (等待 2.44 秒)
# ----> 成功儲存: 063_112年評字第002392號_失能或豁免保費體況認定.pdf
# [64/100] 準備下載: 064_112年評字第003551號_理賠金額認定.pdf (等待 1.97 秒)
# ----> 成功儲存: 064_112年評字第003551號_理賠金額認定.pdf
# [65/100] 準備下載: 065_112年評字第004040號_理賠金額認定.pdf (等待 1.32 秒)
# ----> 成功儲存: 065_112年評字第004040號_理賠金額認定.pdf
# [66/100] 準備下載: 066_112年評字第004129號_投保時已患疾病或在妊娠中.pdf (等待 1.76 秒)
# ----> 成功儲存: 066_112年評字第004129號_投保時已患疾病或在妊娠中.pdf
# [67/100] 準備下載: 067_112年評字第003319號_事故發生原因認定.pdf (等待 2.45 秒)
# ----> 成功儲存: 067_112年評字第003319號_事故發生原因認定.pdf
# [68/100] 準備下載: 068_112年評字第000648號_要保人或受益人變更.pdf (等待 2.33 秒)
# ----> 成功儲存: 068_112年評字第000648號_要保人或受益人變更.pdf
# [69/100] 準備下載: 069_112年評字第001216號_理賠金額認定.pdf (等待 2.13 秒)
# ----> 成功儲存: 069_112年評字第001216號_理賠金額認定.pdf
# [70/100] 準備下載: 070_112年評字第001280號_未遵循服務規範.pdf (等待 2.34 秒)
# ----> 成功儲存: 070_112年評字第001280號_未遵循服務規範.pdf
# [71/100] 準備下載: 071_112年評字第002035號_承保範圍.pdf (等待 1.62 秒)
# ----> 成功儲存: 071_112年評字第002035號_承保範圍.pdf
# [72/100] 準備下載: 072_112年評字第003632號_必要性醫療.pdf (等待 2.25 秒)
# ----> 成功儲存: 072_112年評字第003632號_必要性醫療.pdf
# [73/100] 準備下載: 073_112年評字第003499號_要保人或受益人變更.pdf (等待 1.66 秒)
# ----> 成功儲存: 073_112年評字第003499號_要保人或受益人變更.pdf
# [74/100] 準備下載: 074_112年評字第002751號_必要性醫療.pdf (等待 1.49 秒)
# ----> 成功儲存: 074_112年評字第002751號_必要性醫療.pdf
# [75/100] 準備下載: 075_112年評字第002945號_停效復效爭議.pdf (等待 1.89 秒)
# ----> 成功儲存: 075_112年評字第002945號_停效復效爭議.pdf
# [76/100] 準備下載: 076_112年評字第003328號_事故發生原因認定.pdf (等待 1.57 秒)
# ----> 成功儲存: 076_112年評字第003328號_事故發生原因認定.pdf
# [77/100] 準備下載: 077_112年評字第002091號_事故發生原因認定.pdf (等待 2.33 秒)
# ----> 成功儲存: 077_112年評字第002091號_事故發生原因認定.pdf
# [78/100] 準備下載: 078_112年評字第002589號_承保範圍.pdf (等待 2.23 秒)
# ----> 成功儲存: 078_112年評字第002589號_承保範圍.pdf
# [79/100] 準備下載: 079_112年評字第001655號_停效復效爭議.pdf (等待 2.40 秒)
# ----> 成功儲存: 079_112年評字第001655號_停效復效爭議.pdf
# [80/100] 準備下載: 080_112年評字第002912號_投保時已患疾病或在妊娠中.pdf (等待 1.91 秒)
# ----> 成功儲存: 080_112年評字第002912號_投保時已患疾病或在妊娠中.pdf
# [81/100] 準備下載: 081_112年評字第000661號_解約爭議.pdf (等待 1.83 秒)
# ----> 成功儲存: 081_112年評字第000661號_解約爭議.pdf
# [82/100] 準備下載: 082_112年評字第001489號_因果關係認定.pdf (等待 1.38 秒)
# ----> 成功儲存: 082_112年評字第001489號_因果關係認定.pdf
# [83/100] 準備下載: 083_112年評字第001572號_停效復效爭議.pdf (等待 1.10 秒)
# ----> 成功儲存: 083_112年評字第001572號_停效復效爭議.pdf
# [84/100] 準備下載: 084_112年評字第101031號_遲延給付.pdf (等待 1.87 秒)
# ----> 成功儲存: 084_112年評字第101031號_遲延給付.pdf
# [85/100] 準備下載: 085_112年評字第001928號_遲延給付.pdf (等待 1.59 秒)
# ----> 成功儲存: 085_112年評字第001928號_遲延給付.pdf
# [86/100] 準備下載: 086_112年評字第002296號_失能或豁免保費體況認定.pdf (等待 1.62 秒)
# ----> 成功儲存: 086_112年評字第002296號_失能或豁免保費體況認定.pdf
# [87/100] 準備下載: 087_112年評字第102693號_拒絕承保、解除或終止契約.pdf (等待 1.59 秒)
# ----> 成功儲存: 087_112年評字第102693號_拒絕承保、解除或終止契約.pdf
# [88/100] 準備下載: 088_112年評字第001435號_失能等級認定.pdf (等待 1.46 秒)
# ----> 成功儲存: 088_112年評字第001435號_失能等級認定.pdf
# [89/100] 準備下載: 089_112年評字第001455號_承保範圍.pdf (等待 2.02 秒)
# ----> 成功儲存: 089_112年評字第001455號_承保範圍.pdf
# [90/100] 準備下載: 090_112年評字第001786號_事故發生原因認定.pdf (等待 1.70 秒)
# ----> 成功儲存: 090_112年評字第001786號_事故發生原因認定.pdf
# [91/100] 準備下載: 091_112年評字第002477號_違反告知義務.pdf (等待 1.85 秒)
# ----> 成功儲存: 091_112年評字第002477號_違反告知義務.pdf
# [92/100] 準備下載: 092_112年評字第002448號_事故發生原因認定.pdf (等待 1.26 秒)
# ----> 成功儲存: 092_112年評字第002448號_事故發生原因認定.pdf
# [93/100] 準備下載: 093_112年評字第000652號_必要性醫療.pdf (等待 1.28 秒)
# ----> 成功儲存: 093_112年評字第000652號_必要性醫療.pdf
# [94/100] 準備下載: 094_112年評字第001595號_存款盜領、冒領爭議（含外匯）.pdf (等待 2.48 秒)
# ----> 成功儲存: 094_112年評字第001595號_存款盜領、冒領爭議（含外匯）.pdf
# [95/100] 準備下載: 095_112年評字第000503號_解約爭議.pdf (等待 1.11 秒)
# ----> 成功儲存: 095_112年評字第000503號_解約爭議.pdf
# [96/100] 準備下載: 096_112年評字第001258號_投保時已患疾病或在妊娠中.pdf (等待 1.16 秒)
# ----> 成功儲存: 096_112年評字第001258號_投保時已患疾病或在妊娠中.pdf
# [97/100] 準備下載: 097_112年評字第001277號_癌症或其併發症認定.pdf (等待 1.04 秒)
# ----> 成功儲存: 097_112年評字第001277號_癌症或其併發症認定.pdf
# [98/100] 準備下載: 098_112年評字第001327號_事故發生原因認定.pdf (等待 1.71 秒)
# ----> 成功儲存: 098_112年評字第001327號_事故發生原因認定.pdf
# [99/100] 準備下載: 099_112年評字第001391號_違反告知義務.pdf (等待 2.01 秒)
# ----> 成功儲存: 099_112年評字第001391號_違反告知義務.pdf
# [100/100] 準備下載: 100_112年評字第001179號_承保範圍.pdf (等待 1.77 秒)
# ----> 成功儲存: 100_112年評字第001179號_承保範圍.pdf
#
# 所有任務完成。
